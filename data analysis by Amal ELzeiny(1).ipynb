# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import style

# %%
import matplotlib.colors as mcolors

# %%
from scipy.stats import chi2_contingency

# %%
import seaborn as sns

# %%
import plotly.express as px

# %%
import plotly.graph_objects as go

# %%
df=pd.read_csv('cancer patient data sets.csv')

# %%
df
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %% [markdown]
# what Gender is most suscetible to infection?

# %%
df_Gender=df['Gender'].value_counts()

# %%
df_Gender
# Out:
# Gender
# 1    598
# 2    402
# Name: count, dtype: int64

# %%
df['Gender']=df['Gender'].replace(1,'male')

# %%
df['Gender']=df['Gender'].replace(2,'female')

# %%
df
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33    male              2            4             5
# 1        1        P10   17    male              3            1             5
# 2        2       P100   35    male              4            5             6
# 3        3      P1000   37    male              7            7             7
# 4        4       P101   46    male              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44    male              6            7             7
# 996    996       P996   37  female              6            8             7
# 997    997       P997   25  female              4            5             6
# 998    998       P998   18  female              6            8             7
# 999    999       P999   47    male              6            5             6
#
# ...

# %%
df_Gender1=df['Gender'].value_counts()

# %%
df_Gender1
# Out:
# Gender
# male      598
# female    402
# Name: count, dtype: int64

# %%
color=['brown','beige']

# %%
df_Gender1.plot(kind='pie',radius=1.2,autopct='%0.2f%%',shadow=True,startangle=90,explode=(0.07,0),colors=color)
plt.title("percentage of male and female in dataset ")
# Out:
# Text(0.5, 1.0, 'percentage of male and female in dataset ')

# %%
df['Age'].describe()
# Out:
# count    1000.000000
# mean       37.174000
# std        12.005493
# min        14.000000
# 25%        27.750000
# 50%        36.000000
# 75%        45.000000
# max        73.000000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind='hist',ec='black',color='chocolate')
plt.xlabel('Age')
plt.xticks()
# Out:
# (array([10., 20., 30., 40., 50., 60., 70., 80.]),
#  [Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60'),
#   Text(70.0, 0, '70'),
#   Text(80.0, 0, '80')])

# %%
what the  mean for male and female?
# Out:
# Object `female` not found.

# %%
df.groupby('Gender').Age.mean()
# Out:
# Gender
# female    34.216418
# male      39.162207
# Name: Age, dtype: float64

# %%
which the level has the largest average ages of patients?
# Out:
# Object `patients` not found.

# %%
df_level=df.groupby(df['Level']).Age.mean()

# %%
df_level
# Out:
# Level
# High      37.320548
# Low       35.412541
# Medium    38.620482
# Name: Age, dtype: float64

# %%
lst=[['Low ',35.412541],['High' ,37.320548],[ 'Medium',38.620482]]

# %%
df_mean_age=pd.DataFrame(lst,columns=['Level','mean'])

# %%
df_mean_age
# Out:
#     Level       mean
# 0    Low   35.412541
# 1    High  37.320548
# 2  Medium  38.620482

# %%
ax,fig=plt.subplots(figsize=(9,3))
bars=plt.barh(df_mean_age['Level'] ,df_mean_age['mean'],height=0.8,color='sienna')
fig.spines[['right','top','bottom']].set_visible(False)
fig.xaxis.set_visible(False)
fig.bar_label(bars,padding=-50,color='white',fontsize=12,label_type='edge')
plt.title('the mean of Age in each level ')
plt.show()

# %% [markdown]
# what the number of patients in each level?

# %%
df_gen=df.groupby(df['Level']).Gender.count()

# %%
df_gen
# Out:
# Level
# High      365
# Low       303
# Medium    332
# Name: Gender, dtype: int64

# %%
lst1=[[' Low ',303],['Medium' ,332],['High' ,365]]

# %%
df_num_gender=pd.DataFrame(lst1,columns=['Level','count'])

# %%
df_num_gender
# Out:
#     Level  count
# 0    Low     303
# 1  Medium    332
# 2    High    365

# %%
ax,fig=plt.subplots(figsize=(9,3))
bars=plt.barh(df_num_gender['Level'] ,df_num_gender['count'],height=0.8,color='saddlebrown')
fig.spines[['right','top','bottom']].set_visible(False)
fig.xaxis.set_visible(False)
fig.bar_label(bars,padding=-40,color='white',fontsize=12,label_type='edge')
plt.title('number of patients in Levels ')
plt.show()

# %%
df.groupby(['Level','Gender']).Age.mean()
# Out:
# Level   Gender
# High    female    33.000000
#         male      39.257937
# Low     female    30.233766
#         male      40.765101
# Medium  female    39.777778
#         male      37.827411
# Name: Age, dtype: float64

# %%
df.groupby(['Level','Gender']).Age.std()
# Out:
# Level   Gender
# High    female     9.170021
#         male      10.820932
# Low     female    10.210076
#         male      11.642994
# Medium  female     7.253066
#         male      15.765522
# Name: Age, dtype: float64

# %%
df.groupby(['Level']).Age.std()
# Out:
# Level
# High      10.724253
# Low       12.126736
# Medium    13.015234
# Name: Age, dtype: float64

# %% [markdown]
# number of male in each level of lung cancer

# %%
df_male=df.loc[df['Gender']=='male']

# %%
df_male
# Out:
#      index Patient Id  Age Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33   male              2            4             5
# 1        1        P10   17   male              3            1             5
# 2        2       P100   35   male              4            5             6
# 3        3      P1000   37   male              7            7             7
# 4        4       P101   46   male              6            8             7
# ..     ...        ...  ...    ...            ...          ...           ...
# 990    990       P990   49   male              6            5             6
# 991    991       P991   37   male              8            8             7
# 994    994       P994   33   male              6            7             7
# 995    995       P995   44   male              6            7             7
# 999    999       P999   47   male              6            5             6
#
# ...

# %%
df_male_result=df_male.groupby(['Level']).Gender.count()

# %%
df_male_result
# Out:
# Level
# High      252
# Low       149
# Medium    197
# Name: Gender, dtype: int64

# %%
y=[ 'High','Low','Medium']

# %%
count=[252 , 149, 197 ]

# %%
sns.set(font_scale=1.2)
plt.figure(figsize=(8,8))
plt.pie(x=count, explode=([0.05,0.05,0.05]), labels=y ,colors=['indianred','lightcoral','maroon'],startangle=90 ,autopct='%0.2f%%',pctdistance=0.80,  shadow=True, wedgeprops={'linewidth':5,'edgecolor':'salmon'})
circle=plt.Circle((0,0),0.65,facecolor='white')
plt.title("percentage of male in each Level")
plt.gcf().gca().add_artist(circle)
plt.show()

# %%
df_female=df.loc[df['Gender']=='female']

# %%
df_female
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 6        6       P103   52  female              2            4             5
# 7        7       P104   28  female              3            1             4
# 8        8       P105   35  female              4            5             6
# 11      11       P108   64  female              6            8             7
# 12      12       P109   39  female              4            5             6
# ..     ...        ...  ...     ...            ...          ...           ...
# 992    992       P992   26  female              7            7             7
# 993    993       P993   37  female              7            7             7
# 996    996       P996   37  female              6            8             7
# 997    997       P997   25  female              4            5             6
# 998    998       P998   18  female              6            8             7
#
# ...

# %%
df_female_result=df_female.groupby(['Level']).Gender.count()

# %%
df_female_result
# Out:
# Level
# High      113
# Low       154
# Medium    135
# Name: Gender, dtype: int64

# %%
b=[ 'High','Low','Medium']

# %%
c=[113 ,154 ,135]

# %%
sns.set(font_scale=1.2)
plt.figure(figsize=(8,8))
plt.pie(x=c, explode=([0.03,0.03,0.03]), labels=b ,colors=['salmon','tomato','darksalmon'],startangle=90 ,autopct='%0.2f%%',pctdistance=0.80,  shadow=True, wedgeprops={'linewidth':4,'edgecolor':'white'})
circle=plt.Circle((0,0),0.65,facecolor='white')
plt.title("percentage of female in each Level")
plt.gcf().gca().add_artist(circle)
plt.show()

# %%
df_mhig=df.loc[(df['Gender']=='male')&(df['Level']=='High')]

# %%
df_mhig
# Out:
#      index Patient Id  Age Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 2        2       P100   35   male              4            5             6
# 3        3      P1000   37   male              7            7             7
# 4        4       P101   46   male              6            8             7
# 5        5       P102   35   male              4            5             6
# 10      10       P107   44   male              6            7             7
# ..     ...        ...  ...    ...            ...          ...           ...
# 990    990       P990   49   male              6            5             6
# 991    991       P991   37   male              8            8             7
# 994    994       P994   33   male              6            7             7
# 995    995       P995   44   male              6            7             7
# 999    999       P999   47   male              6            5             6
#
# ...

# %%
df_age_count=df_mhig.groupby(['Age']).Gender.count().rename('count').reset_index()

# %%
df_age_count
# Out:
#     Age  count
# 0    19     10
# 1    24     10
# 2    25      1
# 3    26      8
# 4    27      9
# 5    28     11
# 6    29      1
# 7    33     29
# 8    34     10
# 9    35      9
# 10   36     12
# 11   37     32
# 12   39      2
# 13   42     10
# 14   44     20
# 15   45     10
# 16   46     10
# 17   47     10
# 18   48      8
# 19   49     10
# 20   53      9
# 21   54      1
# 22   62     10
# 23   63      1
# 24   64      9

# %%
df_age_count0= df_age_count.sort_values(by='count',ascending=False).set_index('Age')
df_age_count0
# Out:
#      count
# Age
# 37      32
# 33      29
# 44      20
# 36      12
# 28      11
# 19      10
# 45      10
# 62      10
# 49      10
# 47      10
# 34      10
# 46      10
# 24      10
# 42      10
# 53       9
# 64       9
# 35       9
# 27       9
# 48       8
# 26       8
# 39       2
# 29       1
# 54       1
# 25       1
# 63       1

# %%
df_age_count0.plot(kind='bar',width=1,color='salmon')
plt.title('Age of male in High Level')
# Out:
# Text(0.5, 1.0, 'Age of male in High Level')

# %%
df_ml=df.loc[(df['Gender']=='male')&(df['Level']=='Low')]

# %%
df_ml
# Out:
#      index Patient Id  Age Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33   male              2            4             5
# 33      33       P128   33   male              2            4             5
# 37      37       P131   28   male              6            7             8
# 38      38       P132   32   male              2            3             6
# 42      42       P136   48   male              4            2             3
# ..     ...        ...  ...    ...            ...          ...           ...
# 949    949       P953   61   male              2            3             4
# 950    950       P954   55   male              3            1             1
# 976    976       P978   33   male              2            4             5
# 977    977       P979   45   male              3            1             4
# 979    979       P980   53   male              3            1             4
#
# ...

# %%
df_mldrow=df_ml.groupby(['Age']).Gender.count().rename('count').reset_index()

# %%
df_mldrow
# Out:
#     Age  count
# 0    22      1
# 1    24      1
# 2    26      9
# 3    27      9
# 4    28     10
# 5    32     10
# 6    33     20
# 7    35     11
# 8    38      9
# 9    42     10
# 10   44      9
# 11   45      2
# 12   48     10
# 13   52      9
# 14   53      1
# 15   55     10
# 16   61      9
# 17   62      9

# %%
df_mldrow0=df_mldrow.sort_values(by='count',ascending=False).set_index('Age')

# %%
df_mldrow0
# Out:
#      count
# Age
# 33      20
# 35      11
# 42      10
# 55      10
# 28      10
# 32      10
# 48      10
# 44       9
# 61       9
# 52       9
# 62       9
# 38       9
# 27       9
# 26       9
# 45       2
# 24       1
# 53       1
# 22       1

# %%
df_mldrow0.plot(kind='bar',width=0.9,color='darksalmon')
plt.title('Age of male in Low Level')
# Out:
# Text(0.5, 1.0, 'Age of male in Low Level')

# %%
df_mm=df.loc[(df['Gender']=='male')&(df['Level']=='Medium')]

# %%
df_mm
# Out:
#      index Patient Id  Age Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 1        1        P10   17   male              3            1             5
# 9        9       P106   46   male              2            3             4
# 15      15       P111   73   male              5            6             6
# 16      16       P112   17   male              3            1             5
# 19      19       P115   14   male              2            4             5
# ..     ...        ...  ...    ...            ...          ...           ...
# 964    964       P967   23   male              3            2             4
# 969    969       P971   52   male              6            8             7
# 974    974       P976   35   male              6            8             7
# 983    983       P984   26   male              3            2             4
# 984    984       P985   37   male              1            2             3
#
# ...

# %%
df_mmdrow=df_mm.groupby(['Age']).Gender.count().rename('count').reset_index('Age')

# %%
df_mmdrow
# Out:
#     Age  count
# 0    14      9
# 1    17     10
# 2    19     10
# 3    22      9
# 4    23     10
# 5    24      1
# 6    26      1
# 7    27      7
# 8    28      1
# 9    32      9
# 10   33     19
# 11   35     26
# 12   37      1
# 13   38      3
# 14   39      9
# 15   44     20
# 16   45     10
# 17   46      1
# 18   48      1
# 19   52     10
# 20   62     10
# 21   65     10
# 22   73     10

# %%
df_mmdrow0=df_mmdrow.sort_values(by='count',ascending=False).set_index('Age')
df_mmdrow0
# Out:
#      count
# Age
# 35      26
# 44      20
# 33      19
# 65      10
# 62      10
# 52      10
# 45      10
# 17      10
# 73      10
# 23      10
# 19      10
# 32       9
# 39       9
# 22       9
# 14       9
# 27       7
# 38       3
# 28       1
# 37       1
# 26       1
# 24       1
# 46       1
# 48       1

# %%
df_mmdrow0.plot(kind='bar',width=1,color='tomato')
plt.title('Age of male in Medium Level')
# Out:
# Text(0.5, 1.0, 'Age of male in Medium Level')

# %% [markdown]
# what are the most affected ages of womens in each level?

# %%
df_fhig=df.loc[(df['Gender']=='female')&(df['Level']=='High')]

# %%
df_fhig
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 11      11       P108   64  female              6            8             7
# 21      21       P117   53  female              4            5             6
# 23      23       P119   29  female              6            7             7
# 30      30       P125   35  female              2            6             2
# 57      57        P15   53  female              4            5             6
# ..     ...        ...  ...     ...            ...          ...           ...
# 992    992       P992   26  female              7            7             7
# 993    993       P993   37  female              7            7             7
# 996    996       P996   37  female              6            8             7
# 997    997       P997   25  female              4            5             6
# 998    998       P998   18  female              6            8             7
#
# ...

# %%
df_higdrow=df_fhig.groupby(df['Age']).Gender.count().rename('count').reset_index()

# %%
df_higdrow
# Out:
#     Age  count
# 0    18      9
# 1    25      9
# 2    26     18
# 3    29     18
# 4    35     20
# 5    37     18
# 6    39      9
# 7    46      1
# 8    48      1
# 9    53      9
# 10   64      1

# %%
data_sor=  df_higdrow.sort_values(by="count",ascending=False)

# %%
data_sor
# Out:
#     Age  count
# 4    35     20
# 2    26     18
# 3    29     18
# 5    37     18
# 0    18      9
# 1    25      9
# 6    39      9
# 9    53      9
# 7    46      1
# 8    48      1
# 10   64      1

# %%
data_sor0=data_sor.set_index('Age')

# %%
data_sor0
# Out:
#      count
# Age
# 35      20
# 26      18
# 29      18
# 37      18
# 18       9
# 25       9
# 39       9
# 53       9
# 46       1
# 48       1
# 64       1

# %%
ax=data_sor0.plot(kind='bar',width=0.9,color='indianred')
plt.title('Age of Female in High Level')
# Out:
# Text(0.5, 1.0, 'Age of Female in High Level')

# %%
df_fmedium=df.loc[(df['Gender']=='female')&(df['Level']=='Medium')]

# %%
df_fmedium
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 8        8       P105   35  female              4            5             6
# 12      12       P109   39  female              4            5             6
# 26      26       P121   38  female              2            1             5
# 29      29       P124   28  female              1            6             7
# 32      32       P127   32  female              1            6             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 968    968       P970   52  female              1            2             3
# 970    970       P972   48  female              6            8             7
# 971    971       P973   36  female              2            1             5
# 972    972       P974   31  female              3            2             4
# 973    973       P975   38  female              1            2             3
#
# ...

# %%
df_fmediumdrow = df_fmedium.groupby(['Age']).Gender.count().rename('count').reset_index()

# %%
df_fmediumdrow
# Out:
#     Age  count
# 0    27      2
# 1    28      9
# 2    31      9
# 3    32     12
# 4    33      1
# 5    35      3
# 6    36      9
# 7    38     36
# 8    39      1
# 9    45     11
# 10   46     11
# 11   48     20
# 12   51      1
# 13   52     10

# %%
df_fmedium0=df_fmediumdrow.sort_values(by='count',ascending=False).set_index('Age')

# %%
df_fmedium0
# Out:
#      count
# Age
# 38      36
# 48      20
# 32      12
# 45      11
# 46      11
# 52      10
# 28       9
# 31       9
# 36       9
# 35       3
# 27       2
# 33       1
# 39       1
# 51       1

# %%
ax= df_fmedium0.plot(kind='bar',width=0.9,color='maroon')
plt.title('Age of Female in medium Level')
# Out:
# Text(0.5, 1.0, 'Age of Female in medium Level')

# %%
df_flow=df.loc[(df['Gender']=='female')&(df['Level']=='Low')]

# %%
df_flow
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 6        6       P103   52  female              2            4             5
# 7        7       P104   28  female              3            1             4
# 14      14       P110   27  female              3            1             4
# 34      34       P129   25  female              3            1             4
# 36      36       P130   27  female              3            1             4
# ..     ...        ...  ...     ...            ...          ...           ...
# 939    939       P944   23  female              4            2             3
# 940    940       P945   24  female              3            2             2
# 941    941       P946   35  female              2            1             2
# 942    942       P947   38  female              5            2             3
# 943    943       P948   47  female              2            3             1
#
# ...

# %%
df_flowdrow=df_flow.groupby(['Age']).Gender.count().rename('count').reset_index()

# %%
df_flowdrow
# Out:
#     Age  count
# 0    17     10
# 1    18      9
# 2    22      9
# 3    23      9
# 4    24     18
# 5    25     20
# 6    26      1
# 7    27     21
# 8    28      1
# 9    35      8
# 10   38     21
# 11   43      1
# 12   44      2
# 13   45      9
# 14   47     10
# 15   52      2
# 16   55      1
# 17   61      1
# 18   62      1

# %%
df_flowdrow0=df_flowdrow.sort_values(by='count',ascending=False).set_index('Age')
df_flowdrow0
# Out:
#      count
# Age
# 38      21
# 27      21
# 25      20
# 24      18
# 17      10
# 47      10
# 22       9
# 23       9
# 45       9
# 18       9
# 35       8
# 44       2
# 52       2
# 43       1
# 28       1
# 26       1
# 55       1
# 61       1
# 62       1

# %%
ax= df_flowdrow0.plot(kind='bar',width=1,color='lightcoral')
plt.title('Age of Female in Low Level')
# Out:
# Text(0.5, 1.0, 'Age of Female in Low Level')

# %%
sns.countplot(x='Air Pollution',data=df,color='maroon')
plt.title('the frequency of each category in Air Pollution')
# Out:
# Text(0.5, 1.0, 'the frequency of each category in Air Pollution')

# %%
sns.countplot(x='Alcohol use',data=df,color='indianred')
plt.title('the frequency of each category in Alcohol use')
# Out:
# Text(0.5, 1.0, 'the frequency of each category in Alcohol use')

# %%
sns.countplot(x='Dust Allergy',data=df,color='brown')
plt.title('the frequency of each category in Dust Allergy ')
# Out:
# Text(0.5, 1.0, 'the frequency of each category in Dust Allergy ')

# %%
sns.countplot(x='Genetic Risk',data=df,color='orangered')
plt.title('the frequency of each category in Genetic Risk')
# Out:
# Text(0.5, 1.0, 'the frequency of each category in Genetic Risk')

# %%
sns.countplot(x='Smoking',data=df,color='firebrick')
plt.title('the frequency of each category in Smoking    ')
# Out:
# Text(0.5, 1.0, 'the frequency of each category in Smoking    ')

# %%
sns.countplot(x='Passive Smoker',data=df,color='tomato')
plt.title('the frequency of each category in passive smoker')
# Out:
# Text(0.5, 1.0, 'the frequency of each category in passive smoker')

# %%
sns.countplot(x='Obesity',data=df,color='lightcoral')
plt.title('the frequency of each category in obesity')
# Out:
# Text(0.5, 1.0, 'the frequency of each category in obesity')

# %%
sns.countplot(x='Air Pollution',data=df,color='coral')
plt.title('the frequency of each category in Air Pollution')
# Out:
# Text(0.5, 1.0, 'the frequency of each category in Air Pollution')

# %%
sns.countplot(x='chronic Lung Disease',data=df,color='darksalmon')
plt.title('the frequency of each category in chronic Lung Disease')
# Out:
# Text(0.5, 1.0, 'the frequency of each category in chronic Lung Disease')

# %%
sns.countplot(x='OccuPational Hazards',data=df,color='darksalmon')
plt.title('the frequency of each category in OccuPational Hazards')
# Out:
# Text(0.5, 1.0, 'the frequency of each category in OccuPational Hazards')

# %% [markdown]
# Air Pollution Exposure (Categorical):
# Assess the impact of air pollution on lung cancer risk.
# Group patients by pollution exposure levels and analyze their cancer rates.

# %%
df_air_pollution=df.loc[(df['Air Pollution']==7)]

# %%
df_air_pollution
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 3        3      P1000   37    male              7            7             7
# 104    104       P192   26  female              7            7             7
# 105    105       P193   37  female              7            7             7
# 115    115       P201   37    male              7            7             7
# 215    215       P292   26  female              7            7             7
# 216    216       P293   37  female              7            7             7
# 226    226       P301   37    male              7            7             7
# 326    326       P392   26  female              7            7             7
# 327    327       P393   37  female              7            7             7
# 337    337       P401   37    male              7            7             7
# 437    437       P492   36    male              7            7             7
# ...

# %%
df_air_pollution0=df_air_pollution.groupby([df['Gender'],'Level']).Gender.count().rename('count').reset_index()
df_air_pollution0
# Out:
#    Gender Level  count
# 0  female  High     18
# 1    male  High     12

# %%
j=[['female',18],['male',12]]
df_vi=pd.DataFrame(j,columns=['gender','count']).set_index('gender')
df_vi
# Out:
#         count
# gender
# female     18
# male       12

# %%
df_vi.plot(kind='pie',radius=1.2,autopct='%0.2f%%',startangle=90,explode=(0.05,0),subplots=True)
plt.title('number of male and female are affected by Airpollution equal 7')
# Out:
# Text(0.5, 1.0, 'number of male and female are affected by Airpollution equal 7')

# %%
h=['High']
f=[30]
sns.set(font_scale=1.2)
plt.figure(figsize=(8,8))
plt.pie(x=f, explode=([0]), labels=h,colors=['maroon'],startangle=90 ,autopct='%0.2f%%',pctdistance=0.80,  shadow=True, wedgeprops={'linewidth':2,'edgecolor':'sandybrown'})
circle=plt.Circle((0,0),0.65,facecolor='white')
plt.title('cancer rate when the patient is exposed Airpollution equal 7')
plt.gcf().gca().add_artist(circle)
plt.show()

# %%
df_air_pollution1=df.loc[(df['Air Pollution']==6)]

# %%
df_air_pollution1
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 4        4       P101   46    male              6            8             7
# 10      10       P107   44    male              6            7             7
# 11      11       P108   64  female              6            8             7
# 13      13        P11   34    male              6            7             7
# 17      17       P113   34    male              6            7             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 994    994       P994   33    male              6            7             7
# 995    995       P995   44    male              6            7             7
# 996    996       P996   37  female              6            8             7
# 998    998       P998   18  female              6            8             7
# 999    999       P999   47    male              6            5             6
#
# ...

# %%
df_air_resul=df_air_pollution1.groupby([df['Level'],'Gender']).Gender.count().rename('count').reset_index()
df_air_resul
# Out:
#     Level  Gender  count
# 0    High  female     39
# 1    High    male    207
# 2     Low    male     10
# 3  Medium  female     19
# 4  Medium    male     51

# %%
n=['High','Low',' Medium']
m=[246,10, 70]

# %%
sns.set(font_scale=1.2)
plt.figure(figsize=(8,8))
plt.pie(x=m, explode=([0,0.3,0]), labels=n,colors=['saddlebrown','sandybrown','chocolate'],startangle=90 ,autopct='%0.2f%%',pctdistance=0.80,  shadow=True, wedgeprops={'linewidth':2,'edgecolor':'sandybrown'})
circle=plt.Circle((0,0),0.65,facecolor='white')
plt.title('cancer rate when the patient is exposed Airpollution equal 6')
plt.gcf().gca().add_artist(circle)
plt.show()

# %%
df_air_pollution2=df.loc[(df['Air Pollution']==5)]

# %%
df_air_pollution2
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 15      15       P111   73    male              5            6             6
# 54      54       P147   38  female              5            2             3
# 126    126       P211   73    male              5            6             6
# 165    165       P247   38  female              5            2             3
# 237    237       P311   73    male              5            6             6
# 276    276       P347   38  female              5            2             3
# 348    348       P411   73    male              5            6             6
# 387    387       P447   38  female              5            2             3
# 390    390        P45   38  female              5            2             3
# 459    459       P511   73    male              5            6             6
# 498    498       P547   38  female              5            2             3
# ...

# %%
df_air_aff=df_air_pollution2.groupby([df['Level']]).Gender.count().rename('count').reset_index()
df_air_aff
# Out:
#     Level  count
# 0     Low     10
# 1  Medium     10

# %%
df_air_drow=df_air_aff.set_index('Level')
df_air_drow
# Out:
#         count
# Level
# Low        10
# Medium     10

# %%
df_air_drow.plot(kind='pie',radius=1.2,autopct='%0.2f%%',startangle=90,explode=(0.01,0),subplots=True,colors=['peru','saddlebrown'])
plt.title('cancer rate when the patient is exposed Airpollution equal 5')
# Out:
# Text(0.5, 1.0, 'cancer rate when the patient is exposed Airpollution equal 5')

# %%
df_air_pollution3=df.loc[(df['Air Pollution']==4)]

# %%
df_air_pollution3
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 2        2       P100   35    male              4            5             6
# 5        5       P102   35    male              4            5             6
# 8        8       P105   35  female              4            5             6
# 12      12       P109   39  female              4            5             6
# 21      21       P117   53  female              4            5             6
# ..     ...        ...  ...     ...            ...          ...           ...
# 939    939       P944   23  female              4            2             3
# 945    945        P95   25  female              4            5             6
# 980    980       P981   35  female              4            5             6
# 987    987       P988   29  female              4            5             6
# 997    997       P997   25  female              4            5             6
#
# ...

# %%
df_air_aff0=df_air_pollution3.groupby(df['Level']).Gender.count().rename('count').reset_index().set_index('Level')
df_air_aff0
# Out:
#         count
# Level
# High       50
# Low        20
# Medium     20

# %%
n1=['High','Low','Medium' ]
m1=[50,10,10]
sns.set(font_scale=1.2)
plt.figure(figsize=(8,8))
plt.pie(x=m1, explode=([0,0,0.07]), labels=n1,colors=['sienna','peru','peachpuff'],startangle=90 ,autopct='%0.2f%%',pctdistance=0.80,  shadow=True, wedgeprops={'linewidth':1,'edgecolor':'white'})
circle=plt.Circle((0,0),0.65,facecolor='white')
plt.title('cancer rate when the patient is exposed Airpollution equal 4')
plt.gcf().gca().add_artist(circle)
plt.show()

# %%
df_air_pollution4=df.loc[(df['Air Pollution']==3)]

# %%
df_air_pollution4
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 1        1        P10   17    male              3            1             5
# 7        7       P104   28  female              3            1             4
# 14      14       P110   27  female              3            1             4
# 16      16       P112   17    male              3            1             5
# 27      27       P122   19    male              3            2             4
# ..     ...        ...  ...     ...            ...          ...           ...
# 964    964       P967   23    male              3            2             4
# 972    972       P974   31  female              3            2             4
# 977    977       P979   45    male              3            1             4
# 979    979       P980   53    male              3            1             4
# 983    983       P984   26    male              3            2             4
#
# ...

# %%
df_air_drow0=df_air_pollution4.groupby([df['Level']]).Gender.count().rename('count').reset_index().set_index('Level')
df_air_drow0
# Out:
#         count
# Level
# Low       112
# Medium     61

# %%
df_air_drow0.plot(kind='pie',radius=1.2,autopct='%0.2f%%',startangle=90,explode=(0.02,0),subplots=True,colors=['peachpuff','sandybrown'])
plt.title('cancer rate when the patient is exposed Airpollution equal 3')
# Out:
# Text(0.5, 1.0, 'cancer rate when the patient is exposed Airpollution equal 3')

# %%
df_air_pollution6=df.loc[(df['Air Pollution']==2)]

# %%
df_air_pollution6
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33    male              2            4             5
# 6        6       P103   52  female              2            4             5
# 9        9       P106   46    male              2            3             4
# 19      19       P115   14    male              2            4             5
# 26      26       P121   38  female              2            1             5
# ..     ...        ...  ...     ...            ...          ...           ...
# 953    953       P957   44    male              2            1             5
# 960    960       P963   38  female              2            1             5
# 963    963       P966   35    male              2            1             5
# 971    971       P973   36  female              2            1             5
# 976    976       P978   33    male              2            4             5
#
# ...

# %%
df_air_aff1=df_air_pollution6.groupby(df['Level']).Gender.count().rename('count').reset_index().set_index('Level')
df_air_aff1
# Out:
#         count
# Level
# High       20
# Low       111
# Medium     70

# %%
n2=['High','Low','Medium']
m2=[20,111,70]
sns.set(font_scale=1.2)
plt.figure(figsize=(8,8))
plt.pie(x=m2, explode=([0.08,0,0]), labels=n2,colors=['chocolate','peru','peachpuff'],startangle=90 ,autopct='%0.2f%%',pctdistance=0.80,  shadow=True, wedgeprops={'linewidth':1,'edgecolor':'white'})
circle=plt.Circle((0,0),0.65,facecolor='white')
plt.title('cancer rate when the patient is exposed Airpollution equal 2')
plt.gcf().gca().add_artist(circle)
plt.show()

# %%
df_air_pollution7=df.loc[(df['Air Pollution']==1)]

# %%
df_air_pollution
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 3        3      P1000   37    male              7            7             7
# 104    104       P192   26  female              7            7             7
# 105    105       P193   37  female              7            7             7
# 115    115       P201   37    male              7            7             7
# 215    215       P292   26  female              7            7             7
# 216    216       P293   37  female              7            7             7
# 226    226       P301   37    male              7            7             7
# 326    326       P392   26  female              7            7             7
# 327    327       P393   37  female              7            7             7
# 337    337       P401   37    male              7            7             7
# 437    437       P492   36    male              7            7             7
# ...

# %%
df_air_drow7=df_air_pollution7.groupby(df['Level']).Gender.count().rename('count').reset_index().set_index('Level')
df_air_drow7
df_air_drow7.plot(kind='pie',radius=1.5,autopct='%0.2f%%',startangle=90,explode=(0.02,0),subplots=True,colors=['peachpuff','saddlebrown'])
plt.title('cancer rate when the patient is exposed Airpollution equal 1')
# Out:
# Text(0.5, 1.0, 'cancer rate when the patient is exposed Airpollution equal 1')

# %% [markdown]
# Explore the association between dust allergy and lung cancer
# investigate if patients with allergy have higher lung cancer incidence

# %%
df_dust_allergies=df.loc[(df['Dust Allergy']==7)]

# %%
df_dust_allergies
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 3        3      P1000   37    male              7            7             7
# 4        4       P101   46    male              6            8             7
# 10      10       P107   44    male              6            7             7
# 11      11       P108   64  female              6            8             7
# 13      13        P11   34    male              6            7             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 993    993       P993   37  female              7            7             7
# 994    994       P994   33    male              6            7             7
# 995    995       P995   44    male              6            7             7
# 996    996       P996   37  female              6            8             7
# 998    998       P998   18  female              6            8             7
#
# ...

# %%
df_dst_drow=df_dust_allergies.groupby(df['Level']).Gender.count().rename('count').reset_index().set_index('Level')
df_dst_drow
# Out:
#         count
# Level
# High      275
# Medium    130

# %%
df_dst_drow.plot(kind='pie',radius=1.2,autopct='%0.2f%%',startangle=90,explode=(0.04,0),subplots=True,colors=['coral','lightsalmon'])

plt.title(' patients with Dust Allergy equal 7 rates of lung cancer')
# Out:
# Text(0.5, 1.0, ' patients with Dust Allergy equal 7 rates of lung cancer')

# %%
df_dust_allergies1=df.loc[(df['Dust Allergy']==6)]

# %%
df_dust_allergies1
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 2        2       P100   35    male              4            5             6
# 5        5       P102   35    male              4            5             6
# 8        8       P105   35  female              4            5             6
# 12      12       P109   39  female              4            5             6
# 15      15       P111   73    male              5            6             6
# ..     ...        ...  ...     ...            ...          ...           ...
# 980    980       P981   35  female              4            5             6
# 987    987       P988   29  female              4            5             6
# 990    990       P990   49    male              6            5             6
# 997    997       P997   25  female              4            5             6
# 999    999       P999   47    male              6            5             6
#
# ...

# %%
df_dst_drow1=df_dust_allergies1.groupby([df['Level']]).Gender.count().rename('count').reset_index().set_index('Level')
df_dst_drow1
# Out:
#         count
# Level
# High       70
# Low        10
# Medium     30

# %%
n4=['High','Low','Medium']
m4=[70,10,30]
sns.set(font_scale=1.2)
plt.figure(figsize=(8,8))
plt.pie(x=m4, explode=([0,0.09,0]), labels=n4,colors=['tomato','darksalmon','coral'],startangle=90 ,autopct='%0.2f%%',pctdistance=0.80,  shadow=True, wedgeprops={'linewidth':1,'edgecolor':'white'})
circle=plt.Circle((0,0),0.65,facecolor='white')
plt.title(' patients with Dust Allergy equal 6 rates of lung cancer')
plt.gcf().gca().add_artist(circle)
plt.show()

# %% [markdown]
# analyze lung cancer rates in smokers level and  passive smokers level for each patient

# %%
df_smoker=df[['Gender','Smoking','Passive Smoker','Age','Level']]

# %%
df_smoker
# Out:
#      Gender  Smoking  Passive Smoker  Age   Level
# 0      male        3               2   33     Low
# 1      male        2               4   17  Medium
# 2      male        2               3   35    High
# 3      male        7               7   37    High
# 4      male        8               7   46    High
# ..      ...      ...             ...  ...     ...
# 995    male        7               8   44    High
# 996  female        7               8   37    High
# 997  female        2               3   25    High
# 998  female        8               7   18    High
# 999    male        2               3   47    High
#
# [1000 rows x 5 columns]

# %%
df_smoker1=df_smoker.loc[(df['Smoking']==8)&(df['Passive Smoker']==7)]

# %%
df_smoker1
# Out:
#      Gender  Smoking  Passive Smoker  Age Level
# 4      male        8               7   46  High
# 20     male        8               7   24  High
# 22     male        8               7   62  High
# 46     male        8               7   24  High
# 68     male        8               7   62  High
# ..      ...      ...             ...  ...   ...
# 978  female        8               7   26  High
# 981    male        8               7   46  High
# 988  female        8               7   39  High
# 991    male        8               7   37  High
# 998  female        8               7   18  High
#
# [79 rows x 5 columns]

# %%
smokig_lst=[['Smoking',8 ],['Passive Smoker',7]]
smoking_analysis=pd.DataFrame(smokig_lst,columns= ['features','x']).set_index('features')
smoking_analysis
# Out:
#                 x
# features
# Smoking         8
# Passive Smoker  7

# %%
smoking_analysis.plot(kind='pie',radius=1.2,autopct='%0.2f%%',startangle=90,explode=(0.04,0),subplots=True,colors=['lightcoral','rosybrown'])
plt.title('smoking vs passive smoker in High Level')
# Out:
# Text(0.5, 1.0, 'smoking vs passive smoker in High Level')

# %%
df_smok_age=df_smoker1.groupby(['Age']).Gender.count().rename('count').reset_index().set_index('Age').sort_values(by='count',ascending=False)
df_smok_age
# Out:
#      count
# Age
# 46      11
# 24      10
# 37      10
# 39      10
# 62      10
# 18       9
# 26       9
# 53       8
# 28       1
# 63       1

# %%
ax=df_smok_age.plot(kind='bar',width=0.9,color='lightcoral')

# %%
df_smoker2=df_smoker.loc[(df['Smoking']==6)&(df['Passive Smoker']==8)]
df_smoker2
# Out:
#      Gender  Smoking  Passive Smoker  Age Level
# 30   female        6               8   35  High
# 141  female        6               8   35  High
# 146  female        6               8   35  High
# 252  female        6               8   35  High
# 363  female        6               8   35  High
# 474    male        6               8   35  High
# 585  female        6               8   35  High
# 696  female        6               8   35  High
# 807  female        6               8   35  High
# 918  female        6               8   35  High

# %%
smokig_lst1=[['Smoking',6 ],['Passive Smoker',8]]
smoking_analysis1=pd.DataFrame(smokig_lst1,columns= ['features','x']).set_index('features')
smoking_analysis1.plot(kind='pie',radius=1.2,autopct='%0.2f%%',startangle=270,explode=(0.04,0),subplots=True,colors=['salmon','indianred'])
plt.title('smoking vs passive smoker in High Level')
# Out:
# Text(0.5, 1.0, 'smoking vs passive smoker in High Level')

# %%
df_smok_age2=df_smoker2.groupby(['Age']).Gender.count().rename('count').reset_index().set_index('Age').sort_values(by='count',ascending=False)
df_smok_age2
# Out:
#      count
# Age
# 35      10

# %%
df_smok_age2.plot(kind='bar',width=0.5,color='salmon')
plt.title('The ages of people who have been exposed to')
# Out:
# Text(0.5, 1.0, 'The ages of people who have been exposed to')

# %%
df_smoker3=df_smoker.loc[(df['Smoking']==6)&(df['Passive Smoker']==4)]
df_smoker3
# Out:
#      Gender  Smoking  Passive Smoker  Age Level
# 39   female        6               4   45   Low
# 150  female        6               4   45   Low
# 235  female        6               4   45   Low
# 261  female        6               4   45   Low
# 372    male        6               4   45   Low
# 483  female        6               4   45   Low
# 594  female        6               4   45   Low
# 705  female        6               4   45   Low
# 816  female        6               4   45   Low
# 927  female        6               4   45   Low

# %%
smokig_lst3=[['Smoking',6 ],['Passive Smoker',4]]
smoking_analysis3=pd.DataFrame(smokig_lst,columns= ['features','x']).set_index('features')
smoking_analysis3.plot(kind='pie',radius=1.2,autopct='%0.2f%%',startangle=90,explode=(0.04,0),subplots=True,colors=['mistyrose','darksalmon'])
plt.title('smoking vs passive smoker in low Level')
# Out:
# Text(0.5, 1.0, 'smoking vs passive smoker in low Level')

# %%
df_smok_age3=df_smoker3.groupby(['Age']).Gender.count().rename('count').reset_index().set_index('Age').sort_values(by='count',ascending=False)
df_smok_age3
# Out:
#      count
# Age
# 45      10

# %%
df_smok_age3.plot(kind='bar',width=0.5,color='mistyrose')
plt.title('The ages of people who have been exposed to')
# Out:
# Text(0.5, 1.0, 'The ages of people who have been exposed to')

# %%
df_smok_age2=df_smoker2.groupby(['Age']).Gender.count().rename('count').reset_index().set_index('Age').sort_values(by='count',ascending=False)
df_smok_age2
# Out:
#      count
# Age
# 35      10

# %%
smokig_lst3=[['Smoking',6 ],['Passive Smoker',4]]
smoking_analysis3=pd.DataFrame(smokig_lst,columns= ['features','x']).set_index('features')
smoking_analysis3.plot(kind='pie',radius=1.5,autopct='%0.2f%%',startangle=90,explode=(0.04,0),subplots=True,colors=['mistyrose','darksalmon'])
# Out:
# array([<Axes: ylabel='x'>], dtype=object)

# %%
df_smoker4=df_smoker.loc[(df['Smoking']==5)&(df['Passive Smoker']==4)]
df_smoker4
# Out:
#     Gender  Smoking  Passive Smoker  Age   Level
# 19    male        5               4   14  Medium
# 35    male        5               4   14  Medium
# 130   male        5               4   14  Medium
# 241   male        5               4   14  Medium
# 352   male        5               4   14  Medium
# 463   male        5               4   24  Medium
# 574   male        5               4   14  Medium
# 685   male        5               4   14  Medium
# 796   male        5               4   14  Medium
# 907   male        5               4   14  Medium

# %%
smokig_lst3=[['Smoking',5 ],['Passive Smoker',4]]
smoking_analysis4=pd.DataFrame(smokig_lst,columns= ['features','x']).set_index('features')
smoking_analysis4.plot(kind='pie',radius=1.5,autopct='%0.2f%%',startangle=90,explode=(0.04,0),subplots=True,colors=['mistyrose','orangered'])
plt.title('smoking vs passive smoker in medium Level')
# Out:
# Text(0.5, 1.0, 'smoking vs passive smoker in medium Level')

# %%
df_smok_age4=df_smoker4.groupby(['Age']).Gender.count().rename('count').reset_index().set_index('Age').sort_values(by='count',ascending=False)
df_smok_age4
# Out:
#      count
# Age
# 14       9
# 24       1

# %%
df_smok_age4.plot(kind='bar',width=0.5,color='orangered')
plt.title('The ages of people who have been exposed to')
# Out:
# Text(0.5, 1.0, 'The ages of people who have been exposed to')

# %%
df_smoker5=df_smoker.loc[(df['Smoking']==4)&(df['Passive Smoker']==3)]
df_smoker5
# Out:
#      Gender  Smoking  Passive Smoker  Age Level
# 37     male        4               3   28   Low
# 38     male        4               3   32   Low
# 59   female        4               3   38   Low
# 148    male        4               3   28   Low
# 149    male        4               3   32   Low
# 170    male        4               3   38   Low
# 212    male        4               3   28   Low
# 224    male        4               3   32   Low
# 259    male        4               3   28   Low
# 260    male        4               3   32   Low
# 281    male        4               3   38   Low
# 370    male        4               3   28   Low
# 371    male        4               3   32   Low
# 392    male        4               3   38   Low
# 434    male        4               3   38   Low
# 481    male        4               3   28   Low
# 482    male        4               3   32   Low
# 503    male        4               3   38   Low
# 592    male        4               3   28   Low
# ...

# %%
smokig_lst5=[['Smoking',4 ],['Passive Smoker',3]]
smoking_analysis5=pd.DataFrame(smokig_lst,columns= ['features','x']).set_index('features')
smoking_analysis5.plot(kind='pie',radius=1.2,autopct='%0.2f%%',startangle=90,explode=(0.04,0),subplots=True,colors=['seashell','sandybrown'])
plt.title('smoking vs passive smoker in low level ')
# Out:
# Text(0.5, 1.0, 'smoking vs passive smoker in low level ')

# %%
df_smok_age5=df_smoker5.groupby(['Age']).Gender.count().rename('count').reset_index().set_index('Age').sort_values(by='count',ascending=False)
df_smok_age5
# Out:
#      count
# Age
# 28      10
# 32      10
# 38      10

# %%
df_smok_age5.plot(kind='bar',width=0.5,color='sandybrown')
plt.title('The ages of people who have been exposed to')
# Out:
# Text(0.5, 1.0, 'The ages of people who have been exposed to')

# %%
df_smoker6=df_smoker.loc[(df['Smoking']==4)&(df['Passive Smoker']==2)]
df_smoker6
# Out:
#      Gender  Smoking  Passive Smoker  Age Level
# 52   female        4               2   24   Low
# 163  female        4               2   24   Low
# 274  female        4               2   24   Low
# 368  female        4               2   24   Low
# 385  female        4               2   44   Low
# 496    male        4               2   24   Low
# 607  female        4               2   24   Low
# 718  female        4               2   24   Low
# 829  female        4               2   24   Low
# 940  female        4               2   24   Low

# %%
smokig_lst6=[['Smoking',4 ],['Passive Smoker',2]]
smoking_analysis6=pd.DataFrame(smokig_lst,columns= ['features','x']).set_index('features')
smoking_analysis6.plot(kind='pie',radius=1.2,autopct='%0.2f%%',startangle=100,explode=(0.04,0),subplots=True,colors=['seashell','sienna'])
plt.title('smoking vs passive smoker in low level ')
# Out:
# Text(0.5, 1.0, 'smoking vs passive smoker in low level ')

# %%
df_smok_age6=df_smoker6.groupby(['Age']).Gender.count().rename('count').reset_index().set_index('Age').sort_values(by='count',ascending=False)
df_smok_age6
# Out:
#      count
# Age
# 24       9
# 44       1

# %%
df_smok_age6.plot(kind='bar',width=0.5,color='sienna')
plt.title('The ages of people who have been exposed to')
# Out:
# Text(0.5, 1.0, 'The ages of people who have been exposed to')

# %%
df_smoker7=df_smoker.loc[(df['Smoking']==3)&(df['Passive Smoker']==1)]
df_smoker7
# Out:
#      Gender  Smoking  Passive Smoker  Age Level
# 41   female        3               1   26   Low
# 152    male        3               1   26   Low
# 257    male        3               1   26   Low
# 263    male        3               1   26   Low
# 374    male        3               1   26   Low
# 485    male        3               1   26   Low
# 596    male        3               1   26   Low
# 707    male        3               1   26   Low
# 818    male        3               1   26   Low
# 929    male        3               1   26   Low

# %%
smokig_lst7=[['Smoking',3],['Passive Smoker',1]]
smoking_analysis7=pd.DataFrame(smokig_lst,columns= ['features','x']).set_index('features')
smoking_analysis7.plot(kind='pie',radius=1.2,autopct='%0.2f%%',startangle=120,explode=(0.06,0),subplots=True,colors=['peru','sienna'])
plt.title('smoking vs passive smoker in low level ')
# Out:
# Text(0.5, 1.0, 'smoking vs passive smoker in low level ')

# %%
df_smok_age7=df_smoker6.groupby(['Age']).Gender.count().rename('count').reset_index().set_index('Age').sort_values(by='count',ascending=False)
df_smok_age7
# Out:
#      count
# Age
# 24       9
# 44       1

# %%
df_smok_age7.plot(kind='bar',width=0.5,color='peru')
plt.title('The ages of people who have been exposed to')
# Out:
# Text(0.5, 1.0, 'The ages of people who have been exposed to')

# %% [markdown]
# Explore the link between obesity and lung cancer
# investigate whether obesity affects cancer outcomes

# %%
df_obesity=df[['Gender','Obesity','Level','Age']]

# %%
df_obesity
# Out:
#      Gender  Obesity   Level  Age
# 0      male        4     Low   33
# 1      male        2  Medium   17
# 2      male        7    High   35
# 3      male        7    High   37
# 4      male        7    High   46
# ..      ...      ...     ...  ...
# 995    male        7    High   44
# 996  female        7    High   37
# 997  female        7    High   25
# 998  female        7    High   18
# 999    male        7    High   47
#
# [1000 rows x 4 columns]

# %%
df_obesity7=df_obesity.loc[df['Obesity']==7]

# %%
df_obesity7
# Out:
#      Gender  Obesity Level  Age
# 2      male        7  High   35
# 3      male        7  High   37
# 4      male        7  High   46
# 5      male        7  High   35
# 10     male        7  High   44
# ..      ...      ...   ...  ...
# 995    male        7  High   44
# 996  female        7  High   37
# 997  female        7  High   25
# 998  female        7  High   18
# 999    male        7  High   47
#
# [356 rows x 4 columns]

# %%
df_ob_analysis=df_obesity7.groupby(['Level']).Gender.count().rename('count').reset_index().set_index('Level')
df_ob_analysis
# Out:
#         count
# Level
# High      326
# Medium     30

# %%
n_13=['High','Medium']
m13=[326,30]
sns.set(font_scale=1.2)
plt.figure(figsize=(8,8))
plt.pie(x=m13, explode=([0,0.05]), labels=n_13,colors=['mistyrose','lightcoral'],startangle=90 ,autopct='%0.2f%%',pctdistance=0.80,  shadow=True, wedgeprops={'linewidth':1,'edgecolor':'white'})
circle=plt.Circle((0,0),0.65,facecolor='white')
plt.gcf().gca().add_artist(circle)
plt.title(' obesity when equal 7 affects cancer outcomes')
plt.show()

# %%
df_obesity6=df_obesity.loc[df['Obesity']==6]

# %%
df_obesity6
# Out:
#      Gender  Obesity   Level  Age
# 12   female        6  Medium   39
# 19     male        6  Medium   14
# 31     male        6    High   42
# 35     male        6  Medium   14
# 123    male        6  Medium   39
# 130    male        6  Medium   14
# 142    male        6    High   42
# 157    male        6    High   42
# 234    male        6  Medium   39
# 241    male        6  Medium   14
# 253    male        6    High   42
# 345    male        6  Medium   39
# 352    male        6  Medium   14
# 364    male        6    High   42
# 456    male        6  Medium   39
# 463    male        6  Medium   24
# 475    male        6    High   42
# 567    male        6  Medium   39
# 574    male        6  Medium   14
# 586    male        6    High   42
# 667    male        6  Medium   39
# 678    male        6  Medium   39
# 685    male        6  Medium   14
# 697    male        6    High   42
# 789    male        6  Medium   39
# 796    male        6  Medium   14
# ...

# %%
df_ob_analysis1=df_obesity6.groupby(['Level']).Gender.count().rename('count').reset_index().set_index('Level')
df_ob_analysis1
# Out:
#         count
# Level
# High       10
# Medium     20

# %%
df_ob_analysis1.plot(kind='pie',radius=1.2,autopct='%0.2f%%',startangle=180,explode=(0.06,0),subplots=True,colors=['salmon','sienna'])
plt.title( ' obesity when equal 6 affects cancer outcomes' )
# Out:
# Text(0.5, 1.0, ' obesity when equal 6 affects cancer outcomes')

# %%
df_obesity3=df_obesity.loc[df['Obesity']==3]

# %%
df_obesity3
# Out:
#      Gender  Obesity   Level  Age
# 7    female        3     Low   28
# 9      male        3  Medium   46
# 14   female        3     Low   27
# 20     male        3    High   24
# 27     male        3  Medium   19
# ..      ...      ...     ...  ...
# 973  female        3  Medium   38
# 977    male        3     Low   45
# 979    male        3     Low   53
# 983    male        3  Medium   26
# 984    male        3  Medium   37
#
# [193 rows x 4 columns]

# %%
df_obesity2=df_obesity.loc[df['Obesity']==2]

# %%
df_obesity2
# Out:
#      Gender  Obesity   Level  Age
# 1      male        2  Medium   17
# 16     male        2  Medium   17
# 29   female        2  Medium   28
# 37     male        2     Low   28
# 38     male        2     Low   32
# ..      ...      ...     ...  ...
# 942  female        2     Low   38
# 944    male        2     Low   52
# 946    male        2     Low   44
# 957    male        2  Medium   32
# 966  female        2  Medium   46
#
# [140 rows x 4 columns]

# %%
df_ob_analysis2=df_obesity6.groupby(['Level']).Gender.count().rename('count').reset_index().set_index('Level')
df_ob_analysis2
# Out:
#         count
# Level
# High       10
# Medium     20

# %%
n_15=['High','Medium']
m15=[10,20]
sns.set(font_scale=1.2)
plt.figure(figsize=(8,8))
plt.pie(x=m15, explode=([0,0]), labels=n_15,colors=['brown','beige'],startangle=90 ,autopct='%0.2f%%',pctdistance=0.80,  shadow=True, wedgeprops={'linewidth':1,'edgecolor':'white'})
circle=plt.Circle((0,0),0.65,facecolor='white')
plt.gcf().gca().add_artist(circle)
plt.title(' obesity when equal 2 affects cancer outcomes')
plt.show()

# %% [markdown]
# Alcohol Use (Categorical):
# Examine whether alcohol consumption correlates with lung cancer.
# Compare lung cancer rates in different alcohol use categories.

# %%
df_AlcoholUse=df[['Gender','Alcohol use','Level','Age']]
df_AlcoholUse
# Out:
#      Gender  Alcohol use   Level  Age
# 0      male            4     Low   33
# 1      male            1  Medium   17
# 2      male            5    High   35
# 3      male            7    High   37
# 4      male            8    High   46
# ..      ...          ...     ...  ...
# 995    male            7    High   44
# 996  female            8    High   37
# 997  female            5    High   25
# 998  female            8    High   18
# 999    male            5    High   47
#
# [1000 rows x 4 columns]

# %%
df_Alcohol_analysis= df_AlcoholUse.groupby([df['Level']]).Gender.count().rename('count').reset_index().set_index('Level')
df_Alcohol_analysis
# Out:
#         count
# Level
# High      365
# Low       303
# Medium    332

# %%
df_AlcoholUse0=df_AlcoholUse.loc[df['Alcohol use']==8]
df_AlcoholUse0
# Out:
#      Gender  Alcohol use   Level  Age
# 4      male            8    High   46
# 11   female            8    High   64
# 20     male            8    High   24
# 22     male            8    High   62
# 25     male            8  Medium   65
# ..      ...          ...     ...  ...
# 986    male            8    High   19
# 988  female            8    High   39
# 991    male            8    High   37
# 996  female            8    High   37
# 998  female            8    High   18
#
# [188 rows x 4 columns]

# %%
df_Alcohol_analysis.plot(kind='pie',radius=1.2,autopct='%0.2f%%',startangle=90,explode=(0.04,0),subplots=True,colors=['peachpuff','peru'])
plt.title('LungCancer rate in Alcohol use equal 8')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[199], line 1
# ----> 1 df_Alcohol_analysis.plot(kind='pie',radius=1.2,autopct='%0.2f%%',startangle=90,explode=(0.04,0),subplots=True,colors=['peachpuff','peru'])
#       2 plt.title('LungCancer rate in Alcohol use equal 8')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
# ...

# %%
df_AlcoholUse1=df_AlcoholUse.loc[df['Alcohol use']==7]
df_AlcoholUse1
# Out:
#      Gender  Alcohol use Level  Age
# 3      male            7  High   37
# 10     male            7  High   44
# 13     male            7  High   34
# 17     male            7  High   34
# 18     male            7  High   36
# ..      ...          ...   ...  ...
# 989    male            7  High   37
# 992  female            7  High   26
# 993  female            7  High   37
# 994    male            7  High   33
# 995    male            7  High   44
#
# [167 rows x 4 columns]

# %%
df_Alcohol_analysis1= df_AlcoholUse0.groupby([df['Level']]).Gender.count().rename('count').reset_index().set_index('Level')
df_Alcohol_analysis1
# Out:
#         count
# Level
# High      118
# Medium     70

# %%
n9=['High','Medium']
m9=[118,70]
sns.set(font_scale=1.2)
plt.figure(figsize=(8,8))
plt.pie(x=m9, explode=([0,0.05]), labels=n9,colors=['mistyrose','lightcoral'],startangle=90 ,autopct='%0.2f%%',pctdistance=0.80,  shadow=True, wedgeprops={'linewidth':1,'edgecolor':'white'})
circle=plt.Circle((0,0),0.65,facecolor='white')
plt.gcf().gca().add_artist(circle)
plt.title('LungCancer rate in Alcohol use equal 7')
plt.show()

# %%
df_AlcoholUse2=df_AlcoholUse.loc[df['Alcohol use']==6]
df_AlcoholUse2
# Out:
#      Gender  Alcohol use   Level  Age
# 15     male            6  Medium   73
# 29   female            6  Medium   28
# 30   female            6    High   35
# 32   female            6  Medium   32
# 67   female            6  Medium   33
# ..      ...          ...     ...  ...
# 920  female            6  Medium   32
# 955    male            6  Medium   33
# 957    male            6  Medium   32
# 965  female            6  Medium   48
# 966  female            6  Medium   46
#
# [80 rows x 4 columns]

# %%
df_Alcohol_analysis2= df_AlcoholUse2.groupby([df['Level']]).Gender.count().rename('count').reset_index().set_index('Level')
df_Alcohol_analysis2
# Out:
#         count
# Level
# High       10
# Medium     70

# %%
n_10=['High','Medium']
m10=[10,70]
sns.set(font_scale=1.2)
plt.figure(figsize=(8,8))
plt.pie(x=m10, explode=([0,0.05]), labels=n_10,colors=['mistyrose','lightcoral'],startangle=90 ,autopct='%0.2f%%',pctdistance=0.80,  shadow=True, wedgeprops={'linewidth':1,'edgecolor':'white'})
circle=plt.Circle((0,0),0.65,facecolor='white')
plt.gcf().gca().add_artist(circle)
plt.title('LungCancer rate in Alcohol use equal 6')
plt.show()

# %%
df_AlcoholUse3=df_AlcoholUse.loc[df['Alcohol use']==5]
df_AlcoholUse3
# Out:
#      Gender  Alcohol use   Level  Age
# 2      male            5    High   35
# 5      male            5    High   35
# 8    female            5  Medium   35
# 12   female            5  Medium   39
# 21   female            5    High   53
# ..      ...          ...     ...  ...
# 980  female            5    High   35
# 987  female            5    High   29
# 990    male            5    High   49
# 997  female            5    High   25
# 999    male            5    High   47
#
# [90 rows x 4 columns]

# %%
df_Alcohol_analysis3= df_AlcoholUse3.groupby([df['Level']]).Gender.count().rename('count').reset_index().set_index('Level')
df_Alcohol_analysis3
# Out:
#         count
# Level
# High       70
# Medium     20

# %%
n_11=['High','Medium']
m11=[70,20]
sns.set(font_scale=1.2)
plt.figure(figsize=(8,8))
plt.pie(x=m11, explode=([0,0]), labels=n_11,colors=['mistyrose','lightcoral'],startangle=90 ,autopct='%0.2f%%',pctdistance=0.80,  shadow=True, wedgeprops={'linewidth':1,'edgecolor':'white'})
circle=plt.Circle((0,0),0.65,facecolor='white')
plt.gcf().gca().add_artist(circle)
plt.title('LungCancer rate in Alcohol use equal 5')
plt.show()

# %%
df_AlcoholUse4=df_AlcoholUse.loc[df['Alcohol use']==4]
df_AlcoholUse4
# Out:
#      Gender  Alcohol use   Level  Age
# 0      male            4     Low   33
# 6    female            4     Low   52
# 19     male            4  Medium   14
# 31     male            4    High   42
# 33     male            4     Low   33
# 35     male            4  Medium   14
# 117    male            4     Low   33
# 130    male            4  Medium   14
# 142    male            4    High   42
# 144    male            4     Low   33
# 157    male            4    High   42
# 179    male            4     Low   33
# 228    male            4     Low   33
# 241    male            4  Medium   14
# 253    male            4    High   42
# 255    male            4     Low   33
# 339    male            4     Low   33
# 352    male            4  Medium   14
# 364    male            4    High   42
# 366    male            4     Low   33
# 450    male            4     Low   33
# 463    male            4  Medium   24
# 475    male            4    High   42
# 477    male            4     Low   33
# ...

# %%
df_Alcohol_analysis4= df_AlcoholUse4.groupby([df['Level']]).Gender.count().rename('count').reset_index().set_index('Level')
df_Alcohol_analysis4
# Out:
#         count
# Level
# High       10
# Low        21
# Medium     10

# %%
df_Alcohol_analysis4.plot(kind='pie',radius=1.1,autopct='%0.2f%%',startangle=90,explode=(0,0.04,0),subplots=True,colors=['peachpuff','peru','chocolate'])
plt.title('LungCancer rate in Alcohol use equal 4')
# Out:
# Text(0.5, 1.0, 'LungCancer rate in Alcohol use equal 4')

# %%
df_AlcoholUse5=df_AlcoholUse.loc[df['Alcohol use']==3]
df_AlcoholUse5
# Out:
#      Gender  Alcohol use   Level  Age
# 9      male            3  Medium   46
# 38     male            3     Low   32
# 41   female            3     Low   26
# 47     male            3     Low   35
# 55   female            3     Low   47
# ..      ...          ...     ...  ...
# 935    male            3     Low   35
# 943  female            3     Low   47
# 946    male            3     Low   44
# 947    male            3     Low   38
# 949    male            3     Low   61
#
# [80 rows x 4 columns]

# %%
df_Alcohol_analysis5= df_AlcoholUse5.groupby([df['Level']]).Gender.count().rename('count').reset_index().set_index('Level')
df_Alcohol_analysis5
# Out:
#         count
# Level
# Low        70
# Medium     10

# %%
df_Alcohol_analysis5.plot(kind='pie',radius=1.1,autopct='%0.2f%%',startangle=90,explode=(0,0.04),subplots=True,colors=['peachpuff','peru','chocolate'])
plt.title('LungCancer rate in Alcohol use equal 3')
# Out:
# Text(0.5, 1.0, 'LungCancer rate in Alcohol use equal 3')

# %%
df_AlcoholUse6=df_AlcoholUse.loc[df['Alcohol use']==2]
df_AlcoholUse6
# Out:
#      Gender  Alcohol use   Level  Age
# 27     male            2  Medium   19
# 39   female            2     Low   45
# 42     male            2     Low   48
# 43   female            2     Low   17
# 48   female            2     Low   24
# ..      ...          ...     ...  ...
# 968  female            2  Medium   52
# 972  female            2  Medium   31
# 973  female            2  Medium   38
# 983    male            2  Medium   26
# 984    male            2  Medium   37
#
# [202 rows x 4 columns]

# %%
df_Alcohol_analysis6= df_AlcoholUse6.groupby([df['Level']]).Gender.count().rename('count').reset_index().set_index('Level')
df_Alcohol_analysis6
# Out:
#         count
# Level
# Low       110
# Medium     92

# %%
n_12=['Low','Medium']
m12=[110,92]
sns.set(font_scale=1.2)
plt.figure(figsize=(8,8))
plt.pie(x=m12, explode=([0,0]), labels=n_12,colors=['orangered','lightsalmon'],startangle=90 ,autopct='%0.2f%%',pctdistance=0.80,  shadow=True, wedgeprops={'linewidth':1,'edgecolor':'white'})
circle=plt.Circle((0,0),0.65,facecolor='white')
plt.gcf().gca().add_artist(circle)
plt.title('LungCancer rate in Alcohol use equal 2')
plt.show()

# %% [markdown]
# correlation between Age and Level

# %%
df_data_c=df[['Age','Level']]
df_data_c['Level']=df_data_c['Level'].replace('High',0)
df_data_c['Level']=df_data_c['Level'].replace('Medium',1)
df_data_c['Level']=df_data_c['Level'].replace('Low',2)
df_data_c
# Out:
# C:\Users\lapshop\AppData\Local\Temp\ipykernel_5124\1027662694.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data_c['Level']=df_data_c['Level'].replace('High',0)
# C:\Users\lapshop\AppData\Local\Temp\ipykernel_5124\1027662694.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data_c['Level']=df_data_c['Level'].replace('Medium',1)
# C:\Users\lapshop\AppData\Local\Temp\ipykernel_5124\1027662694.py:4: SettingWithCopyWarning:
# ...

# %%
df_cor=df_data_c.corr()
df_cor
# Out:
#             Age     Level
# Age    1.000000 -0.060048
# Level -0.060048  1.000000

# %%
sns.heatmap(df_cor,annot=True)
plt.title(' correlation between Age and Level ')
# Out:
# Text(0.5, 1.0, ' correlation between Age and Level ')

# %%
sns.scatterplot(x='Age', y='Level' ,data=df_cor );

# %% [markdown]
# relation between features and Level of lung cancer

# %%
mindim=min(df_cross_tab0.shape)-1

# %%
mindim0=min(df_cross_tab0.shape)-1

# %%
n=1000

# %%
df_cross_tab0=pd.crosstab(index=df['Level'],columns=df['Gender'])

# %%
df_cross_tab0
# Out:
# Gender  female  male
# Level
# High       113   252
# Low        154   149
# Medium     135   197

# %%
chi_sq_result0=chi2_contingency(df_cross_tab0)

# %%
p,x=chi_sq_result0[1],'regect' if chi_sq_result0[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result0[1]} and hence  {x}  the null Hypothesis with {chi_sq_result0[2] } degrees of freedom ")
# Out:
# the p_value is 1.2251212802771069e-06 and hence  regect  the null Hypothesis with 2 degrees of freedom

# %%
v0=np.sqrt((chi_sq_result0[0])/(mindim0*n))

# %%
v0
# Out:
# 0.16499982251239148

# %%
df_cross_tab=pd.crosstab(index=df['Level'],columns=df['Air Pollution'])

# %%
df_cross_tab
# Out:
# Air Pollution    1    2    3   4   5    6   7   8
# Level
# High             0   20    0  50   0  246  30  19
# Low             40  111  112  20  10   10   0   0
# Medium         101   70   61  20  10   70   0   0

# %%
chi_sq_result=chi2_contingency(df_cross_tab)

# %%
p,x=chi_sq_result[1],'regect' if chi_sq_result[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result[1]} and hence  {x}  the null Hypothesis with {chi_sq_result[2] } degrees of freedom ")
# Out:
# the p_value is 5.9971570004966065e-133 and hence  regect  the null Hypothesis with 14 degrees of freedom

# %%
v=np.sqrt((chi_sq_result[0])/(mindim*n))

# %%
v
# Out:
# 0.8157640702160657

# %%
df_cross_tab1=pd.crosstab(index=df['Level'],columns=df['Alcohol use'])

# %%
df_cross_tab1
# Out:
# Alcohol use   1    2   3   4   5   6    7    8
# Level
# High          0    0   0  10  70  10  157  118
# Low          92  110  70  21   0   0   10    0
# Medium       60   92  10  10  20  70    0   70

# %%
chi_sq_result1=chi2_contingency(df_cross_tab1)

# %%
p,x=chi_sq_result1[1],'regect' if chi_sq_result1[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result1[1]} and hence  {x}  the null Hypothesis with {chi_sq_result1[2] } degrees of freedom ")
# Out:
# the p_value is 3.0552472876211455e-177 and hence  regect  the null Hypothesis with 14 degrees of freedom

# %%
chi_sq_result1[0]
# Out:
# 872.6917495190664

# %%
v1=np.sqrt((chi_sq_result1[0])/(mindim*n))

# %%
v1
# Out:
# 0.934179720139046

# %%
df_cross_tab2=pd.crosstab(index=df['Level'],columns=df['Genetic Risk'])

# %%
df_cross_tab2
# Out:
# Genetic Risk   1    2   3   4   5   6    7
# Level
# High           0    0   0   0  80  68  217
# Low           40  121  92  20   0  20   10
# Medium         0   91  81  20  20  20  100

# %%
chi_sq_result2=chi2_contingency(df_cross_tab2)

# %%
p,x=chi_sq_result2[1],'regect' if chi_sq_result2[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result2[1]} and hence  {x}  the null Hypothesis with {chi_sq_result2[2] } degrees of freedom ")
# Out:
# the p_value is 1.4449590655403639e-127 and hence  regect  the null Hypothesis with 12 degrees of freedom

# %%
v2=np.sqrt((chi_sq_result2[0])/(mindim*n))

# %%
v2
# Out:
# 0.795070339200812

# %%
df_cross_tab3=pd.crosstab(index=df['Level'],columns=df['Smoking'])

# %%
df_cross_tab3
# Out:
# Smoking    1   2    3   4   5   6    7   8
# Level
# High       0  70    0  19   0  10  187  79
# Low       61  81   71  40   0  30   20   0
# Medium   120  71  101   0  10  20    0  10

# %%
chi_sq_result3=chi2_contingency(df_cross_tab3)

# %%
p,x=chi_sq_result3[1],'regect' if chi_sq_result3[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result3[1]} and hence  {x}  the null Hypothesis with {chi_sq_result3[2] } degrees of freedom ")
# Out:
# the p_value is 5.246169667912979e-137 and hence  regect  the null Hypothesis with 14 degrees of freedom

# %%
v3=np.sqrt((chi_sq_result3[0])/(mindim*n))

# %%
v3
# Out:
# 0.8273430491277004

# %%
df_cross_tab4=pd.crosstab(index=df['Level'],columns=df['Passive Smoker'])

# %%
df_cross_tab4
# Out:
# Passive Smoker   1    2   3    4   5   6    7    8
# Level
# High             0    0  70    0   0   0  187  108
# Low             60  122  30   61  20  10    0    0
# Medium           0  162  40  100  10  20    0    0

# %%
chi_sq_result4=chi2_contingency(df_cross_tab4)

# %%
p,x=chi_sq_result4[1],'regect' if chi_sq_result4[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result4[1]} and hence  {x}  the null Hypothesis with {chi_sq_result4[2] } degrees of freedom ")
# Out:
# the p_value is 9.798219647240706e-200 and hence  regect  the null Hypothesis with 14 degrees of freedom

# %%
v4=np.sqrt((chi_sq_result4[0])/(mindim*n))

# %%
v4
# Out:
# 0.9887566491697334

# %%
df_cross_tab5=pd.crosstab(index=df['Level'],columns=df['Obesity'])

# %%
df_cross_tab5
# Out:
# Obesity   1    2    3    4   5   6    7
# Level
# High      0    0   19   10   0  10  326
# Low      70  100   72   61   0   0    0
# Medium    0   40  102  120  20  20   30

# %%
chi_sq_result5=chi2_contingency(df_cross_tab5)

# %%
p,x=chi_sq_result5[1],'regect' if chi_sq_result5[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result5[1]} and hence  {x}  the null Hypothesis with {chi_sq_result5[2] } degrees of freedom ")
# Out:
# the p_value is 2.8794186980664995e-203 and hence  regect  the null Hypothesis with 12 degrees of freedom

# %%
v5=np.sqrt((chi_sq_result5[0])/(mindim*n))

# %%
v5
# Out:
# 0.9925605706286681

# %%
df_cross_tab6=pd.crosstab(index=df['Level'],columns=df['OccuPational Hazards'])

# %%
df_cross_tab6
# Out:
# OccuPational Hazards   1   2   3   4   5   6    7   8
# Level
# High                   0   0  10   0  70  10  275   0
# Low                   50  71  81  71  10   0   20   0
# Medium                 0  61  60  41  50  20   70  30

# %%
chi_sq_result6=chi2_contingency(df_cross_tab6)

# %%
p,x=chi_sq_result6[1],'regect' if chi_sq_result6[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result6[1]} and hence  {x}  the null Hypothesis with {chi_sq_result6[2] } degrees of freedom ")
# Out:
# the p_value is 1.0523203579242225e-140 and hence  regect  the null Hypothesis with 14 degrees of freedom

# %%
v6=np.sqrt((chi_sq_result6[0])/(mindim*n))

# %%
v6
# Out:
# 0.8377494546606054

# %%
df_cross_tab7=pd.crosstab(index=df['Level'],columns=df['chronic Lung Disease'])

# %%
df_cross_tab7
# Out:
# chronic Lung Disease   1   2   3   4   5    6   7
# Level
# High                   0   0   0  70  10  198  87
# Low                   50  82  81  20  40   10  20
# Medium                 0  91  60  51  30  100   0

# %%
chi_sq_result7=chi2_contingency(df_cross_tab7)

# %%
p,x=chi_sq_result7[1],'regect' if chi_sq_result7[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result7[1]} and hence  {x}  the null Hypothesis with {chi_sq_result7[2] } degrees of freedom ")
# Out:
# the p_value is 1.5853456732363079e-117 and hence  regect  the null Hypothesis with 12 degrees of freedom

# %%
v7=np.sqrt((chi_sq_result7[0])/(mindim*n))

# %%
v7
# Out:
# 0.7649376052600357

# %%
df_cross_tab8=pd.crosstab(index=df['Level'],columns=df['Fatigue'])

# %%
df_cross_tab8
# Out:
# Fatigue   1    2   3    4   5   6    8   9
# Level
# High      0   30  60   58  69   0  109  39
# Low      80  111  92   20   0   0    0   0
# Medium   30   70  60  102  20  50    0   0

# %%
chi_sq_result8=chi2_contingency(df_cross_tab8)

# %%
p,x=chi_sq_result8[1],'regect' if chi_sq_result8[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result8[1]} and hence  {x}  the null Hypothesis with {chi_sq_result8[2] } degrees of freedom ")
# Out:
# the p_value is 9.319843382936078e-134 and hence  regect  the null Hypothesis with 14 degrees of freedom

# %%
v8=np.sqrt((chi_sq_result8[0])/(mindim*n))

# %%
v8
# Out:
# 0.8180846136988555

# %%
df_cross_tab9=pd.crosstab(index=df['Level'],columns=df['Weight Loss'])

# %%
df_cross_tab9
# Out:
# Weight Loss   1    2   3   4   5   6    7   8
# Level
# High          0  118  40  19  39  39  110   0
# Low          80  122  40  31  10  10    0  10
# Medium       41   40  70  10  51   0  120   0

# %%
chi_sq_result9=chi2_contingency(df_cross_tab9)

# %%
p,x=chi_sq_result9[1],'regect' if chi_sq_result9[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result9[1]} and hence  {x}  the null Hypothesis with {chi_sq_result9[2] } degrees of freedom ")
# Out:
# the p_value is 6.670508785965849e-69 and hence  regect  the null Hypothesis with 14 degrees of freedom

# %%
v9=np.sqrt((chi_sq_result8[0])/(mindim*n))

# %%
v9
# Out:
# 0.8180846136988555

# %%
df_cross_tab10=pd.crosstab(index=df['Level'],columns=df['Shortness of Breath'])

# %%
df_cross_tab10
# Out:
# Shortness of Breath   1    2   3   4   5    6   7   9
# Level
# High                  0   40  39  70  77   30  39  70
# Low                  80   92  91  10  10   10  10   0
# Medium                0  111  10  10   0  161  40   0

# %%
chi_sq_result10=chi2_contingency(df_cross_tab10)

# %%
p,x=chi_sq_result10[1],'regect' if chi_sq_result10[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result9[1]} and hence  {x}  the null Hypothesis with {chi_sq_result9[2] } degrees of freedom ")
# Out:
# the p_value is 6.670508785965849e-69 and hence  regect  the null Hypothesis with 14 degrees of freedom

# %%
v10=np.sqrt((chi_sq_result10[0])/(mindim*n))

# %%
v10
# Out:
# 0.9068395815902072

# %%
df_cross_tab11=pd.crosstab(index=df['Level'],columns=df['Wheezing'])

# %%
df_cross_tab11
# Out:
# Wheezing   1    2   3   4    5   6    7   8
# Level
# High      99   89  10   0    0  58  109   0
# Low       40  131  50  82    0   0    0   0
# Medium    10   20   0  81  171  10   30  10

# %%
chi_sq_result11=chi2_contingency(df_cross_tab11)

# %%
p,x=chi_sq_result11[1],'regect' if chi_sq_result9[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result11[1]} and hence  {x}  the null Hypothesis with {chi_sq_result11[2] } degrees of freedom ")
# Out:
# the p_value is 2.1656830012892582e-180 and hence  regect  the null Hypothesis with 14 degrees of freedom

# %%
v11=np.sqrt((chi_sq_result11[0])/(mindim*n))

# %%
v11
# Out:
# 0.9420167465793945

# %%
df_cross_tab12=pd.crosstab(index=df['Level'],columns=df['Swallowing Difficulty'])

# %%
df_cross_tab12
# Out:
# Swallowing Difficulty   1   2   3   4   5   6   7   8
# Level
# High                   70  39  19  99  29  30  29  50
# Low                    71  91  61  40  20  10   0  10
# Medium                 80  30  10  50  61  51   0  50

# %%
chi_sq_result12=chi2_contingency(df_cross_tab12)

# %%
p,x=chi_sq_result12[1],'regect' if chi_sq_result12[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result12[1]} and hence  {x}  the null Hypothesis with {chi_sq_result12[2] } degrees of freedom ")
# Out:
# the p_value is 7.346588920254707e-48 and hence  regect  the null Hypothesis with 14 degrees of freedom

# %%
v12=np.sqrt((chi_sq_result12[0])/(mindim*n))

# %%
v12
# Out:
# 0.5123672401045333

# %%
df_cross_tab13=pd.crosstab(index=df['Level'],columns=df['Clubbing of Finger Nails'])

# %%
df_cross_tab13
# Out:
# Clubbing of Finger Nails   1    2   3    4   5   6   7   8   9
# Level
# High                       0  119   0  119  58   0  30  29  10
# Low                       71  101  70   40  21   0   0   0   0
# Medium                    60   20  30   61  41  10  10  30  70

# %%
chi_sq_result13=chi2_contingency(df_cross_tab13)

# %%
p,x=chi_sq_result13[1],'regect' if chi_sq_result13[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result13[1]} and hence  {x}  the null Hypothesis with {chi_sq_result13[2] } degrees of freedom ")
# Out:
# the p_value is 8.260080543775454e-88 and hence  regect  the null Hypothesis with 16 degrees of freedom

# %%
v13=np.sqrt((chi_sq_result13[0])/(mindim*n))

# %%
v13
# Out:
# 0.6783671153137923

# %%
df_cross_tab14=pd.crosstab(index=df['Level'],columns=df['Frequent Cold'])

# %%
df_cross_tab14
# Out:
# Frequent Cold   1    2    3    4   5    6   7
# Level
# High           29   30   39  119   0  119  29
# Low            60  132   71   20  20    0   0
# Medium         50   30  120   41   0   51  40

# %%
chi_sq_result14=chi2_contingency(df_cross_tab14)

# %%
p,x=chi_sq_result14[1],'regect' if chi_sq_result14[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result14[1]} and hence  {x}  the null Hypothesis with {chi_sq_result14[2] } degrees of freedom ")
# Out:
# the p_value is 4.387242864050228e-90 and hence  regect  the null Hypothesis with 12 degrees of freedom

# %%
v14=np.sqrt((chi_sq_result14[0])/(mindim*n))

# %%
v14
# Out:
# 0.6754824738261835

# %%
df_cross_tab15=pd.crosstab(index=df['Level'],columns=df['Dry Cough'])

# %%
df_cross_tab15
# Out:
# Dry Cough   1    2   3   4   5   6    7
# Level
# High       39   60  30   0  50  58  128
# Low        60   70  71  61  20  21    0
# Medium     20  121   0  80  61  10   40

# %%
chi_sq_result15=chi2_contingency(df_cross_tab15)

# %%
p,x=chi_sq_result15[1],'regect' if chi_sq_result15[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result15[1]} and hence  {x}  the null Hypothesis with {chi_sq_result15[2] } degrees of freedom ")
# Out:
# the p_value is 4.3475654350918364e-79 and hence  regect  the null Hypothesis with 12 degrees of freedom

# %%
v15=np.sqrt((chi_sq_result15[0])/(mindim*n))

# %%
v15
# Out:
# 0.6359540465158362

# %%
df_cross_tab16=pd.crosstab(index=df['Level'],columns=df['Snoring'])

# %%
df_cross_tab16
# Out:
# Snoring    1    2    3   4   5   6   7
# Level
# High      30  109  100  39  58  19  10
# Low      100  101   61  41   0   0   0
# Medium    40   90   50  51  81  20   0

# %%
chi_sq_result16=chi2_contingency(df_cross_tab16)

# %%
p,x=chi_sq_result16[1],'regect' if chi_sq_result16[1]<0.05  else   'accept'

# %%
print(f"the p_value is {chi_sq_result16[1]} and hence  {x}  the null Hypothesis with {chi_sq_result16[2] } degrees of freedom ")
# Out:
# the p_value is 6.4254307292643705e-34 and hence  regect  the null Hypothesis with 12 degrees of freedom

# %%
v16=np.sqrt((chi_sq_result16[0])/(mindim*n))

# %%
v16
# Out:
# 0.4345880851606511

# %%
df_cross_tab17=pd.crosstab(index=df['Level'],columns=df['Coughing of Blood'])

# %%
df_cross_tab17
# Out:
# Coughing of Blood   1   2    3    4   5   6    7    8   9
# Level
# High                0   0   10    0   0  29  157  109  60
# Low                71  91   30   71  20  10    0   10   0
# Medium              0  30  131  101  30  10   30    0   0

# %%
chi_sq_result17=chi2_contingency(df_cross_tab17)

# %%
print(f"the p_value is {chi_sq_result17[1]} and hence  {x}  the null Hypothesis with {chi_sq_result17[2] } degrees of freedom ")
# Out:
# the p_value is 2.1238918003472384e-210 and hence  regect  the null Hypothesis with 16 degrees of freedom

# %%
v17=np.sqrt((chi_sq_result17[0])/(mindim*n))

# %%
v17
# Out:
# 1.0178686011295501

# %%
cramer_v=[['Gender',v0],['Air Pollution',v],['Alcohol use',v1],['Genetic Risk',v2],['Smoking',v3],['Passive Smoker ',v4],['Obesity',v5],['OccuPational Hazards',v6],['chronic Lung Disease',v7]]

# %%
cramer_v
# Out:
# [['Gender', 0.16499982251239148],
#  ['Air Pollution', 0.8157640702160657],
#  ['Alcohol use', 0.934179720139046],
#  ['Genetic Risk', 0.795070339200812],
#  ['Smoking', 0.8273430491277004],
#  ['Passive Smoker ', 0.9887566491697334],
#  ['Obesity', 0.9925605706286681],
#  ['OccuPational Hazards', 0.8377494546606054],
#  ['chronic Lung Disease', 0.7649376052600357]]

# %%
df_cv=pd.DataFrame(cramer_v,columns=['features','cramer_v with level' ]).sort_values(by='cramer_v with level',ascending=False)

# %%
df_cv
# Out:
#                features  cramer_v with level
# 6               Obesity             0.992561
# 5       Passive Smoker              0.988757
# 2           Alcohol use             0.934180
# 7  OccuPational Hazards             0.837749
# 4               Smoking             0.827343
# 1         Air Pollution             0.815764
# 3          Genetic Risk             0.795070
# 8  chronic Lung Disease             0.764938
# 0                Gender             0.165000

# %%
df_cvc=df_cv.set_index('features')

# %%
df_cvc
# Out:
#                       cramer_v with level
# features
# Obesity                          0.992561
# Passive Smoker                   0.988757
# Alcohol use                      0.934180
# OccuPational Hazards             0.837749
# Smoking                          0.827343
# Air Pollution                    0.815764
# Genetic Risk                     0.795070
# chronic Lung Disease             0.764938
# Gender                           0.165000

# %%
sns.heatmap(df_cvc,annot=True,cmap='BrBG',annot_kws={'fontsize':16})
# Out:
# <Axes: ylabel='features'>

# %%
cramer_v1=[['Coughing of Blood',v17],['Snoring', v16 ],['Dry Cough',v15],['Frequent Cold',v14],['Clubbing of Finger Nails',v13],['Swallowing Difficulty',v12],['Wheezing',v11],['Shortness of Breath',v10] ,['Weight Loss',v9],['Fatigue',v8]]

# %%
cramer_v1
# Out:
# [['Coughing of Blood', 1.0178686011295501],
#  ['Snoring', 0.4345880851606511],
#  ['Dry Cough', 0.6359540465158362],
#  ['Frequent Cold', 0.6754824738261835],
#  ['Clubbing of Finger Nails', 0.6783671153137923],
#  ['Swallowing Difficulty', 0.5123672401045333],
#  ['Wheezing', 0.9420167465793945],
#  ['Shortness of Breath', 0.9068395815902072],
#  ['Weight Loss', 0.8180846136988555],
#  ['Fatigue', 0.8180846136988555]]

# %%
df_cv1=pd.DataFrame(cramer_v1,columns=['features','cramer_v with level' ]).sort_values(by='cramer_v with level',ascending=False)

# %%
df_cv1
# Out:
#                    features  cramer_v with level
# 0         Coughing of Blood             1.017869
# 6                  Wheezing             0.942017
# 7       Shortness of Breath             0.906840
# 8               Weight Loss             0.818085
# 9                   Fatigue             0.818085
# 4  Clubbing of Finger Nails             0.678367
# 3             Frequent Cold             0.675482
# 2                 Dry Cough             0.635954
# 5     Swallowing Difficulty             0.512367
# 1                   Snoring             0.434588

# %%
df_cvc1=df_cv1.set_index('features')

# %%
df_cvc1
# Out:
#                           cramer_v with level
# features
# Coughing of Blood                    1.017869
# Wheezing                             0.942017
# Shortness of Breath                  0.906840
# Weight Loss                          0.818085
# Fatigue                              0.818085
# Clubbing of Finger Nails             0.678367
# Frequent Cold                        0.675482
# Dry Cough                            0.635954
# Swallowing Difficulty                0.512367
# Snoring                              0.434588

# %%
sns.heatmap(df_cvc1,annot=True,cmap='BrBG',annot_kws={'fontsize':16})
# Out:
# <Axes: ylabel='features'>
